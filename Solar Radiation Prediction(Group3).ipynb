# %% [markdown]
# ## Solar Power Generation Project

# %%
#importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading datasets
data2017 = pd.read_csv('2017_Data.csv')
data2018 = pd.read_csv('2018_Data.csv')
data2019 = pd.read_csv('2019_Data.csv')

# %%
data2017.head(3)
# Out:
#    Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  Dew Point  \
# 0  2017      1    1     0       0    0             0           8          2
# 1  2017      1    1     0      30    0             0           8          2
# 2  2017      1    1     1       0    0             0           3          2
#
#    Solar Zenith Angle  Fill Flag  Surface Albedo  Wind Speed  \
# 0              166.36          0           0.157         1.1
# 1              163.49          0           0.157         1.1
# 2              158.95          0           0.157         1.1
#
#    Precipitable Water  Wind Direction  Relative Humidity  Temperature  \
# 0               1.430            42.8              100.0            4
# 1               1.416            42.8              100.0            4
# 2               1.403            35.1              100.0            4
#
#    Pressure
# 0       930
# 1       930
# 2       930

# %%
data2017.shape
# Out:
# (17520, 18)

# %%
data2018.head(3)
# Out:
#    Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  Dew Point  \
# 0  2018      1    1     0       0    0             0           0      -10.1
# 1  2018      1    1     0      30    0             0           0      -10.1
# 2  2018      1    1     1       0    0             0           0       -9.5
#
#    Solar Zenith Angle  Fill Flag  Surface Albedo  Wind Speed  \
# 0              166.39          0            0.17         1.5
# 1              163.50          0            0.17         1.5
# 2              158.96          0            0.17         1.6
#
#    Precipitable Water  Wind Direction  Relative Humidity  Temperature  \
# 0                 0.6               4              26.75          7.9
# 1                 0.6             181              27.68          7.4
# 2                 0.6             357              30.04          6.9
#
#    Pressure
# 0       948
# 1       948
# 2       948

# %%
data2018.shape
# Out:
# (17520, 18)

# %%
data2019.head(3)
# Out:
#    Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  Dew Point  \
# 0  2019      1    1     0       0    0             0           0      -12.6
# 1  2019      1    1     0      30    0             0           0      -12.6
# 2  2019      1    1     1       0    0             0           0      -12.6
#
#    Solar Zenith Angle  Fill Flag  Surface Albedo  Wind Speed  \
# 0              166.40          0            0.17         3.2
# 1              163.50          0            0.17         3.2
# 2              158.95          0            0.17         3.2
#
#    Precipitable Water  Wind Direction  Relative Humidity  Temperature  \
# 0                 0.4             358              40.83         -0.9
# 1                 0.4             357              41.13         -1.0
# 2                 0.4             356              41.79         -1.2
#
#    Pressure
# 0       943
# 1       943
# 2       943

# %%
data2017.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'GHI', 'Clearsky GHI',
#        'Cloud Type', 'Dew Point', 'Solar Zenith Angle', 'Fill Flag',
#        'Surface Albedo', 'Wind Speed', 'Precipitable Water', 'Wind Direction',
#        'Relative Humidity', 'Temperature', 'Pressure'],
#       dtype='object')

# %%
data2018.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'GHI', 'Clearsky GHI',
#        'Cloud Type', 'Dew Point', 'Solar Zenith Angle', 'Fill Flag',
#        'Surface Albedo', 'Wind Speed', 'Precipitable Water', 'Wind Direction',
#        'Relative Humidity', 'Temperature', 'Pressure'],
#       dtype='object')

# %%
data2019.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'GHI', 'Clearsky GHI',
#        'Cloud Type', 'Dew Point', 'Solar Zenith Angle', 'Fill Flag',
#        'Surface Albedo', 'Wind Speed', 'Precipitable Water', 'Wind Direction',
#        'Relative Humidity', 'Temperature', 'Pressure'],
#       dtype='object')

# %%
datasets = [data2017,data2018,data2019]
df = pd.concat(datasets)

# %%
df['Year'].unique()
# Out:
# array([2017, 2018, 2019], dtype=int64)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'GHI', 'Clearsky GHI',
#        'Cloud Type', 'Dew Point', 'Solar Zenith Angle', 'Fill Flag',
#        'Surface Albedo', 'Wind Speed', 'Precipitable Water', 'Wind Direction',
#        'Relative Humidity', 'Temperature', 'Pressure'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Year         Month           Day          Hour        Minute  \
# count  52560.000000  52560.000000  52560.000000  52560.000000  52560.000000
# mean    2018.000000      6.526027     15.720548     11.500000     15.000000
# std        0.816504      3.447884      8.796331      6.922252     15.000143
# min     2017.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2017.000000      4.000000      8.000000      5.750000      0.000000
# 50%     2018.000000      7.000000     16.000000     11.500000     15.000000
# 75%     2019.000000     10.000000     23.000000     17.250000     30.000000
# max     2019.000000     12.000000     31.000000     23.000000     30.000000
#
#                 GHI  Clearsky GHI    Cloud Type     Dew Point  \
# count  52560.000000  52560.000000  52560.000000  52560.000000
# mean     233.314669    256.760331      2.096766     -0.440409
# std      317.244451    331.939308      2.975211      7.479977
# min        0.000000      0.000000      0.000000    -26.100000
# 25%        0.000000      0.000000      0.000000     -5.100000
# 50%        0.000000      0.000000      0.000000     -0.400000
# 75%      456.000000    525.000000      4.000000      4.200000
# max     1067.000000   1067.000000      9.000000     23.000000
#
#        Solar Zenith Angle     Fill Flag  Surface Albedo    Wind Speed  \
# count        52560.000000  52560.000000    52560.000000  52560.000000
# mean            89.689162      0.227340        0.179440      2.588415
# std             38.039271      0.850164        0.022069      1.807017
# min             12.990000      0.000000        0.157000      0.000000
# 25%             59.160000      0.000000        0.180000      1.300000
# 50%             89.560000      0.000000        0.180000      2.000000
# 75%            120.380000      0.000000        0.181000      3.500000
# max            167.150000      5.000000        0.870000     13.400000
#
#        Precipitable Water  Wind Direction  Relative Humidity  Temperature  \
# count        52560.000000    52560.000000       52560.000000  52560.00000
# mean             1.386231      183.342154          32.234062     20.46121
# std              0.893441      106.711185          20.801842     10.86176
# min              0.100000        0.000000           3.160000     -2.60000
# 25%              0.800000       96.000000          16.130000     11.70000
# 50%              1.158000      205.000000          27.060000     19.80000
# 75%              1.700000      245.000000          43.500000     28.90000
# max              6.600000      360.000000         100.000000     47.00000
#
#            Pressure
# count  52560.000000
# mean     940.898973
# std        5.191706
# min      920.000000
# 25%      939.000000
# 50%      940.000000
# 75%      944.000000
# max      960.000000

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'GHI', 'Clearsky GHI',
#        'Cloud Type', 'Dew Point', 'Solar Zenith Angle', 'Fill Flag',
#        'Surface Albedo', 'Wind Speed', 'Precipitable Water', 'Wind Direction',
#        'Relative Humidity', 'Temperature', 'Pressure'],
#       dtype='object')

# %%
df.shape
# Out:
# (52560, 18)

# %%
df.head()
# Out:
#    Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  Dew Point  \
# 0  2017      1    1     0       0    0             0           8        2.0
# 1  2017      1    1     0      30    0             0           8        2.0
# 2  2017      1    1     1       0    0             0           3        2.0
# 3  2017      1    1     1      30    0             0           1        2.0
# 4  2017      1    1     2       0    0             0           0        2.0
#
#    Solar Zenith Angle  Fill Flag  Surface Albedo  Wind Speed  \
# 0              166.36          0           0.157         1.1
# 1              163.49          0           0.157         1.1
# 2              158.95          0           0.157         1.1
# 3              153.60          0           0.157         1.1
# 4              147.87          0           0.157         1.1
#
#    Precipitable Water  Wind Direction  Relative Humidity  Temperature  \
# 0               1.430            42.8              100.0          4.0
# 1               1.416            42.8              100.0          4.0
# 2               1.403            35.1              100.0          4.0
# 3               1.390            35.1              100.0          4.0
# 4               1.378            22.3              100.0          4.0
#
#    Pressure
# 0       930
# 1       930
# 2       930
# 3       930
# 4       930

# %%
datetime_series = pd.Series(pd.date_range(start = '2017-01-01',periods = 52560,freq = '30min'),name = 'DateSeries')

# %%
datetime_series
# Out:
# 0       2017-01-01 00:00:00
# 1       2017-01-01 00:30:00
# 2       2017-01-01 01:00:00
# 3       2017-01-01 01:30:00
# 4       2017-01-01 02:00:00
#                 ...
# 52555   2019-12-31 21:30:00
# 52556   2019-12-31 22:00:00
# 52557   2019-12-31 22:30:00
# 52558   2019-12-31 23:00:00
# 52559   2019-12-31 23:30:00
# Name: DateSeries, Length: 52560, dtype: datetime64[ns]

# %%
df.tail()
# Out:
#        Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# 17515  2019     12   31    21      30    0             0           4
# 17516  2019     12   31    22       0    0             0           0
# 17517  2019     12   31    22      30    0             0           0
# 17518  2019     12   31    23       0    0             0           0
# 17519  2019     12   31    23      30    0             0           0
#
#        Dew Point  Solar Zenith Angle  Fill Flag  Surface Albedo  Wind Speed  \
# 17515      -12.3              148.27          0            0.17         2.5
# 17516      -12.7              153.99          0            0.17         2.7
# 17517      -12.7              159.31          0            0.17         2.9
# 17518      -12.7              163.78          0            0.17         3.0
# 17519      -12.7              166.51          0            0.17         3.1
#
#        Precipitable Water  Wind Direction  Relative Humidity  Temperature  \
# 17515                 0.4            16.0              39.28         -0.1
# 17516                 0.4            11.0              38.54         -0.3
# 17517                 0.4             6.0              39.10         -0.5
# 17518                 0.4             2.0              39.78         -0.7
# 17519                 0.4           180.0              40.12         -0.8
#
#        Pressure
# 17515       942
# 17516       942
# 17517       942
# 17518       942
# 17519       943

# %%
datetime_series
# Out:
# 0       2017-01-01 00:00:00
# 1       2017-01-01 00:30:00
# 2       2017-01-01 01:00:00
# 3       2017-01-01 01:30:00
# 4       2017-01-01 02:00:00
#                 ...
# 52555   2019-12-31 21:30:00
# 52556   2019-12-31 22:00:00
# 52557   2019-12-31 22:30:00
# 52558   2019-12-31 23:00:00
# 52559   2019-12-31 23:30:00
# Name: DateSeries, Length: 52560, dtype: datetime64[ns]

# %%
df = df.set_index(datetime_series)

# %%
# df

# %%
df.loc['2017-01-01 00:00:00':'2017-01-01 01:30:00']
# Out:
#                      Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  \
# DateSeries
# 2017-01-01 00:00:00  2017      1    1     0       0    0             0
# 2017-01-01 00:30:00  2017      1    1     0      30    0             0
# 2017-01-01 01:00:00  2017      1    1     1       0    0             0
# 2017-01-01 01:30:00  2017      1    1     1      30    0             0
#
#                      Cloud Type  Dew Point  Solar Zenith Angle  Fill Flag  \
# DateSeries
# 2017-01-01 00:00:00           8        2.0              166.36          0
# 2017-01-01 00:30:00           8        2.0              163.49          0
# 2017-01-01 01:00:00           3        2.0              158.95          0
# 2017-01-01 01:30:00           1        2.0              153.60          0
#
#                      Surface Albedo  Wind Speed  Precipitable Water  \
# DateSeries
# 2017-01-01 00:00:00           0.157         1.1               1.430
# 2017-01-01 00:30:00           0.157         1.1               1.416
# 2017-01-01 01:00:00           0.157         1.1               1.403
# 2017-01-01 01:30:00           0.157         1.1               1.390
#
#                      Wind Direction  Relative Humidity  Temperature  Pressure
# DateSeries
# 2017-01-01 00:00:00            42.8              100.0          4.0       930
# 2017-01-01 00:30:00            42.8              100.0          4.0       930
# 2017-01-01 01:00:00            35.1              100.0          4.0       930
# 2017-01-01 01:30:00            35.1              100.0          4.0       930

# %%
df.head(1)
# Out:
#             Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# DateSeries
# 2017-01-01  2017      1    1     0       0    0             0           8
#
#             Dew Point  Solar Zenith Angle  Fill Flag  Surface Albedo  \
# DateSeries
# 2017-01-01        2.0              166.36          0           0.157
#
#             Wind Speed  Precipitable Water  Wind Direction  Relative Humidity  \
# DateSeries
# 2017-01-01         1.1                1.43            42.8              100.0
#
#             Temperature  Pressure
# DateSeries
# 2017-01-01          4.0       930

# %%
#dropping irrelavant columns from the dataframe
new_df = df.drop(columns = ['Clearsky GHI','Fill Flag'])

# %%
new_df
# Out:
#                      Year  Month  Day  Hour  Minute  GHI  Cloud Type  \
# DateSeries
# 2017-01-01 00:00:00  2017      1    1     0       0    0           8
# 2017-01-01 00:30:00  2017      1    1     0      30    0           8
# 2017-01-01 01:00:00  2017      1    1     1       0    0           3
# 2017-01-01 01:30:00  2017      1    1     1      30    0           1
# 2017-01-01 02:00:00  2017      1    1     2       0    0           0
# ...                   ...    ...  ...   ...     ...  ...         ...
# 2019-12-31 21:30:00  2019     12   31    21      30    0           4
# 2019-12-31 22:00:00  2019     12   31    22       0    0           0
# 2019-12-31 22:30:00  2019     12   31    22      30    0           0
# 2019-12-31 23:00:00  2019     12   31    23       0    0           0
# 2019-12-31 23:30:00  2019     12   31    23      30    0           0
#
#                      Dew Point  Solar Zenith Angle  Surface Albedo  \
# DateSeries
# 2017-01-01 00:00:00        2.0              166.36           0.157
# 2017-01-01 00:30:00        2.0              163.49           0.157
# 2017-01-01 01:00:00        2.0              158.95           0.157
# 2017-01-01 01:30:00        2.0              153.60           0.157
# 2017-01-01 02:00:00        2.0              147.87           0.157
# ...                        ...                 ...             ...
# 2019-12-31 21:30:00      -12.3              148.27           0.170
# 2019-12-31 22:00:00      -12.7              153.99           0.170
# 2019-12-31 22:30:00      -12.7              159.31           0.170
# 2019-12-31 23:00:00      -12.7              163.78           0.170
# 2019-12-31 23:30:00      -12.7              166.51           0.170
#
#                      Wind Speed  Precipitable Water  Wind Direction  \
# DateSeries
# 2017-01-01 00:00:00         1.1               1.430            42.8
# 2017-01-01 00:30:00         1.1               1.416            42.8
# 2017-01-01 01:00:00         1.1               1.403            35.1
# 2017-01-01 01:30:00         1.1               1.390            35.1
# 2017-01-01 02:00:00         1.1               1.378            22.3
# ...                         ...                 ...             ...
# 2019-12-31 21:30:00         2.5               0.400            16.0
# 2019-12-31 22:00:00         2.7               0.400            11.0
# 2019-12-31 22:30:00         2.9               0.400             6.0
# 2019-12-31 23:00:00         3.0               0.400             2.0
# 2019-12-31 23:30:00         3.1               0.400           180.0
#
#                      Relative Humidity  Temperature  Pressure
# DateSeries
# 2017-01-01 00:00:00             100.00          4.0       930
# 2017-01-01 00:30:00             100.00          4.0       930
# 2017-01-01 01:00:00             100.00          4.0       930
# 2017-01-01 01:30:00             100.00          4.0       930
# 2017-01-01 02:00:00             100.00          4.0       930
# ...                                ...          ...       ...
# 2019-12-31 21:30:00              39.28         -0.1       942
# 2019-12-31 22:00:00              38.54         -0.3       942
# 2019-12-31 22:30:00              39.10         -0.5       942
# 2019-12-31 23:00:00              39.78         -0.7       942
# 2019-12-31 23:30:00              40.12         -0.8       943
#
# [52560 rows x 16 columns]

# %%
#Features we need in model
# Year Day Hour-Minute Surface Albedo Cloud Type Dew Point Zenith Angle,Month Pressure Wind Direction Wind Speed Relative Humidity Temperature Precip. Water

# %%
#reordering the index of columns in the dataframe
column_names = ['Year','Day','Hour','Minute','Surface Albedo','Cloud Type','Dew Point','Solar Zenith Angle','Month','Pressure','Wind Direction','Wind Speed','Relative Humidity','Temperature','Precipitable Water','GHI']
new_df = new_df.reindex(columns=column_names)

# %%
new_df.head()
# Out:
#                      Year  Day  Hour  Minute  Surface Albedo  Cloud Type  \
# DateSeries
# 2017-01-01 00:00:00  2017    1     0       0           0.157           8
# 2017-01-01 00:30:00  2017    1     0      30           0.157           8
# 2017-01-01 01:00:00  2017    1     1       0           0.157           3
# 2017-01-01 01:30:00  2017    1     1      30           0.157           1
# 2017-01-01 02:00:00  2017    1     2       0           0.157           0
#
#                      Dew Point  Solar Zenith Angle  Month  Pressure  \
# DateSeries
# 2017-01-01 00:00:00        2.0              166.36      1       930
# 2017-01-01 00:30:00        2.0              163.49      1       930
# 2017-01-01 01:00:00        2.0              158.95      1       930
# 2017-01-01 01:30:00        2.0              153.60      1       930
# 2017-01-01 02:00:00        2.0              147.87      1       930
#
#                      Wind Direction  Wind Speed  Relative Humidity  \
# DateSeries
# 2017-01-01 00:00:00            42.8         1.1              100.0
# 2017-01-01 00:30:00            42.8         1.1              100.0
# 2017-01-01 01:00:00            35.1         1.1              100.0
# 2017-01-01 01:30:00            35.1         1.1              100.0
# 2017-01-01 02:00:00            22.3         1.1              100.0
#
#                      Temperature  Precipitable Water  GHI
# DateSeries
# 2017-01-01 00:00:00          4.0               1.430    0
# 2017-01-01 00:30:00          4.0               1.416    0
# 2017-01-01 01:00:00          4.0               1.403    0
# 2017-01-01 01:30:00          4.0               1.390    0
# 2017-01-01 02:00:00          4.0               1.378    0

# %%
# new_df.to_csv('cleaned_weather_data.csv')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52560 entries, 2017-01-01 00:00:00 to 2019-12-31 23:30:00
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                52560 non-null  int64
#  1   Day                 52560 non-null  int64
#  2   Hour                52560 non-null  int64
#  3   Minute              52560 non-null  int64
#  4   Surface Albedo      52560 non-null  float64
#  5   Cloud Type          52560 non-null  int64
#  6   Dew Point           52560 non-null  float64
#  7   Solar Zenith Angle  52560 non-null  float64
#  8   Month               52560 non-null  int64
#  9   Pressure            52560 non-null  int64
#  10  Wind Direction      52560 non-null  float64
#  11  Wind Speed          52560 non-null  float64
#  12  Relative Humidity   52560 non-null  float64
#  13  Temperature         52560 non-null  float64
#  14  Precipitable Water  52560 non-null  float64
#  15  GHI                 52560 non-null  int64
# dtypes: float64(8), int64(8)
# memory usage: 8.3 MB

# %%
new_df.isna().sum()
# Out:
# Year                  0
# Day                   0
# Hour                  0
# Minute                0
# Surface Albedo        0
# Cloud Type            0
# Dew Point             0
# Solar Zenith Angle    0
# Month                 0
# Pressure              0
# Wind Direction        0
# Wind Speed            0
# Relative Humidity     0
# Temperature           0
# Precipitable Water    0
# GHI                   0
# dtype: int64

# %%
new_df.head(3)
# Out:
#                      Year  Day  Hour  Minute  Surface Albedo  Cloud Type  \
# DateSeries
# 2017-01-01 00:00:00  2017    1     0       0           0.157           8
# 2017-01-01 00:30:00  2017    1     0      30           0.157           8
# 2017-01-01 01:00:00  2017    1     1       0           0.157           3
#
#                      Dew Point  Solar Zenith Angle  Month  Pressure  \
# DateSeries
# 2017-01-01 00:00:00        2.0              166.36      1       930
# 2017-01-01 00:30:00        2.0              163.49      1       930
# 2017-01-01 01:00:00        2.0              158.95      1       930
#
#                      Wind Direction  Wind Speed  Relative Humidity  \
# DateSeries
# 2017-01-01 00:00:00            42.8         1.1              100.0
# 2017-01-01 00:30:00            42.8         1.1              100.0
# 2017-01-01 01:00:00            35.1         1.1              100.0
#
#                      Temperature  Precipitable Water  GHI
# DateSeries
# 2017-01-01 00:00:00          4.0               1.430    0
# 2017-01-01 00:30:00          4.0               1.416    0
# 2017-01-01 01:00:00          4.0               1.403    0

# %% [markdown]
# ## Training and Testing Model

# %%
x = new_df.drop(columns = ['GHI'])
y = new_df[['GHI']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 10)

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predict = model.predict(x_test)

# %% [markdown]
# ## Accuracy Score of Model

# %%
from sklearn.metrics import r2_score

# %%
model.score(x_test,y_test)
# Out:
# 0.9784887489318241

# %%
r2_score(y_test,y_predict)
# Out:
# 0.9784887489318241

# %% [markdown]
# ## Checking the accuracy of Model

# %% [markdown]
# #### Cross - checking first 10 values

# %%
y_predict[:10]
# Out:
# array([  0.,   0., 628.,   0.,   0.,   0., 995., 508., 485., 658.])

# %%
y_test.iloc[:10]
# Out:
#                       GHI
# DateSeries
# 2018-02-23 00:30:00     0
# 2019-10-12 05:30:00     0
# 2019-01-31 11:30:00   627
# 2018-01-16 17:00:00     0
# 2017-03-16 05:00:00     0
# 2017-01-27 20:30:00     0
# 2019-07-21 12:30:00  1009
# 2017-11-17 13:00:00   516
# 2019-04-17 07:30:00   473
# 2017-09-04 10:30:00   765

# %% [markdown]
# #### Cross- checking last 10 values

# %%
y_predict[:-10:-1]
# Out:
# array([762.,   0.,   0., 626., 783.,   0.,   0.,  22.,   0.])

# %%
y_test.iloc[:-10:-1]
# Out:
#                      GHI
# DateSeries
# 2018-07-22 14:30:00  769
# 2019-08-05 03:30:00    0
# 2018-12-07 01:00:00    0
# 2018-10-03 09:30:00  668
# 2017-08-27 14:00:00  763
# 2018-01-03 20:00:00    0
# 2019-08-05 20:30:00    0
# 2017-03-23 06:00:00   24
# 2017-10-07 04:30:00    0

# %% [markdown]
# ## Conclusion:
#
# Since the values are continuous in nature, the predicted values are almost same as true values.
# And the accuracy of predicting the output is 97%.
